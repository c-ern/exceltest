# %%
import os
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'Fehlerkennkarte extern NEU.xls',
#  'Untitled.ipynb']

# %%
import pandas

# %%
df3=pandas.read_excel("Fehlerkennkarte extern NEU.xls",sheetname=0)

# %%
df3
# Out:
#              Unnamed: 0        Unnamed: 1            Unnamed: 2    Unnamed: 3  \
# 0                   NaN               NaN                   NaN           NaN
# 1                   NaN               NaN                   NaN           NaN
# 2                   NaN               NaN                   NaN           NaN
# 3                   NaN               NaN                   NaN           NaN
# 4                Datum:  LS / WE- Nummer:  Prüfauftrags-nummer:  Chargen-Nr.:
# 5   2015-09-14 00:00:00              8244                 50283           NaN
# 6   2015-09-22 00:00:00              8358                 50334           NaN
# 7   2015-09-24 00:00:00              9920                 50921           NaN
# 8   2015-09-28 00:00:00              8316                 50307           NaN
# 9   2016-02-18 00:00:00             14483                 52984           NaN
# 10  2016-03-31 00:00:00             17218                 53825           NaN
# ...

# %%
df4=pandas.read_excel("Fehlerkennkarte extern NEU.xls",sheetname="71231")

# %%
df4
# Out:
#               Unnamed: 0        Unnamed: 1            Unnamed: 2  \
# 0                    NaN               NaN                   NaN
# 1                    NaN               NaN                   NaN
# 2                    NaN               NaN                   NaN
# 3                    NaN               NaN                   NaN
# 4                 Datum:  LS / WE- Nummer:  Prüfauftrags-nummer:
# 5    2015-09-14 00:00:00              9554                 50802
# 6    2015-09-15 00:00:00              9613                 50828
# 7    2015-09-17 00:00:00              9733                 50867
# 8    2015-09-18 00:00:00              9792                 50890
# 9    2015-09-18 00:00:00              8974                 50906
# 10   2015-10-02 00:00:00             10240                 51083
# 11   2015-10-02 00:00:00             10274                 51105
# 12   2015-10-05 00:00:00             10312                 51136
# ...

# %%
df4[4:-1]
# Out:
#               Unnamed: 0        Unnamed: 1            Unnamed: 2  \
# 4                 Datum:  LS / WE- Nummer:  Prüfauftrags-nummer:
# 5    2015-09-14 00:00:00              9554                 50802
# 6    2015-09-15 00:00:00              9613                 50828
# 7    2015-09-17 00:00:00              9733                 50867
# 8    2015-09-18 00:00:00              9792                 50890
# 9    2015-09-18 00:00:00              8974                 50906
# 10   2015-10-02 00:00:00             10240                 51083
# 11   2015-10-02 00:00:00             10274                 51105
# 12   2015-10-05 00:00:00             10312                 51136
# 13   2015-10-06 00:00:00             10354                 51161
# 14   2015-10-07 00:00:00             10415                 51195
# 15   2015-10-08 00:00:00             10469                 51225
# 16   2015-10-14 00:00:00             10682                 51344
# ...

# %%
df5=df4[4:-1]

# %%
df5
# Out:
#               Unnamed: 0        Unnamed: 1            Unnamed: 2  \
# 4                 Datum:  LS / WE- Nummer:  Prüfauftrags-nummer:
# 5    2015-09-14 00:00:00              9554                 50802
# 6    2015-09-15 00:00:00              9613                 50828
# 7    2015-09-17 00:00:00              9733                 50867
# 8    2015-09-18 00:00:00              9792                 50890
# 9    2015-09-18 00:00:00              8974                 50906
# 10   2015-10-02 00:00:00             10240                 51083
# 11   2015-10-02 00:00:00             10274                 51105
# 12   2015-10-05 00:00:00             10312                 51136
# 13   2015-10-06 00:00:00             10354                 51161
# 14   2015-10-07 00:00:00             10415                 51195
# 15   2015-10-08 00:00:00             10469                 51225
# 16   2015-10-14 00:00:00             10682                 51344
# ...

# %%
df5.iloc[0]
# Out:
# Unnamed: 0                           Datum:
# Unnamed: 1                 LS / WE- Nummer:
# Unnamed: 2             Prüfauftrags-nummer:
# Unnamed: 3                     Chargen-Nr.:
# Unnamed: 4                Gesamt-stückzahl:
# Teilename:          Beschädigungam Lagerpad
# Unnamed: 6          Aufplattierung Lagerpad
# Unnamed: 7         Beschädigung Außenkontur
# Unnamed: 8         Beschädigung Innenkontur
# Axiallager            Beschädigung Ölablauf
# Unnamed: 10        Beschädigung Dichtfläche
# Unnamed: 11        Beschädigung Querbohrung
# Unnamed: 12           Beschädigung Öltasche
# Unnamed: 13                     Ölige Teile
# Unnamed: 14                      Rückstände
# Unnamed: 15                     Sonstiges 1
# Unnamed: 16                     Sonstiges 2
# Unnamed: 17                     Sonstiges 3
# Unnamed: 18                     Sonstiges 4
# Unnamed: 19                     Sonstiges 5
# Fehlerkennkarte      Summe\nn.i.O.\n[Stück]
# ...

# %%
df5.columns = df5.iloc[0]

# %%
df5
# Out:
# 4                 Datum:  LS / WE- Nummer:  Prüfauftrags-nummer:  \
# 4                 Datum:  LS / WE- Nummer:  Prüfauftrags-nummer:
# 5    2015-09-14 00:00:00              9554                 50802
# 6    2015-09-15 00:00:00              9613                 50828
# 7    2015-09-17 00:00:00              9733                 50867
# 8    2015-09-18 00:00:00              9792                 50890
# 9    2015-09-18 00:00:00              8974                 50906
# 10   2015-10-02 00:00:00             10240                 51083
# 11   2015-10-02 00:00:00             10274                 51105
# 12   2015-10-05 00:00:00             10312                 51136
# 13   2015-10-06 00:00:00             10354                 51161
# 14   2015-10-07 00:00:00             10415                 51195
# 15   2015-10-08 00:00:00             10469                 51225
# 16   2015-10-14 00:00:00             10682                 51344
# ...

# %%
df5.loc[5,"Datum:"]
# Out:
# Timestamp('2015-09-14 00:00:00')

# %%
df5.loc[5:7,"Datum:"]
# Out:
# 5    2015-09-14 00:00:00
# 6    2015-09-15 00:00:00
# 7    2015-09-17 00:00:00
# Name: Datum:, dtype: object

# %%
df5.loc[5,"Datum:":"Gesamt-stückzahl:"]
# Out:
# 4
# Datum:                  2015-09-14 00:00:00
# LS / WE- Nummer:                       9554
# Prüfauftrags-nummer:                  50802
# Chargen-Nr.:                            NaN
# Gesamt-stückzahl:                      3480
# Name: 5, dtype: object

# %%
df5.loc[5:6,"Datum:":"Gesamt-stückzahl:"]
# Out:
# 4               Datum: LS / WE- Nummer: Prüfauftrags-nummer: Chargen-Nr.:  \
# 5  2015-09-14 00:00:00             9554                50802          NaN
# 6  2015-09-15 00:00:00             9613                50828          NaN
#
# 4 Gesamt-stückzahl:
# 5              3480
# 6              3480

# %%
fsk = pandas.ExcelFile("Fehlerkennkarte extern NEU.xls")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d5cf9f0420ef> in <module>()
# ----> 1 fsk = pandas.ExcelFile("Fehlerkennkarte extern NEU.xls")
#
# NameError: name 'pandas' is not defined

# %%
import pandas as pd

# %%
fsk = pd.ExcelFile("Fehlerkennkarte extern NEU.xls")

# %%
fsk

# %%
fsk.sheet_names
# Out:
# ['83002',
#  '38816',
#  '38945',
#  '38947',
#  '38966',
#  '38983',
#  '71231',
#  '38908',
#  '38002',
#  '38000',
#  '38812',
#  '38823',
#  '38875',
#  '38896',
#  '38893',
#  '38906',
#  '71229']

# %%
dftest=fsk.parse("38896")

# %%
dftest
# Out:
#              Unnamed: 0        Unnamed: 1            Unnamed: 2    Unnamed: 3  \
# 0                   NaN               NaN                   NaN           NaN
# 1                   NaN               NaN                   NaN           NaN
# 2                   NaN               NaN                   NaN           NaN
# 3                   NaN               NaN                   NaN           NaN
# 4                Datum:  LS / WE- Nummer:  Prüfauftrags-nummer:  Chargen-Nr.:
# 5   2015-09-17 00:00:00              9223                 50637           NaN
# 6                   NaN               NaN                   NaN           NaN
# 7                   NaN               NaN                   NaN           NaN
# 8                   NaN               NaN                   NaN           NaN
# 9                   NaN               NaN                   NaN           NaN
# 10                  NaN               NaN                   NaN           NaN
# ...

# %%
for sheets in fsk:
    print(sheets)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-669905231d4a> in <module>()
# ----> 1 for sheets in fsk:
#       2     print(sheets)
#
# TypeError: 'ExcelFile' object is not iterable

# %%
for sheets in fsk.sheet_names:
    print(sheets)
# Out:
# 83002
# 38816
# 38945
# 38947
# 38966
# 38983
# 71231
# 38908
# 38002
# 38000
# 38812
# 38823
# 38875
# 38896
# 38893
# 38906
# 71229

# %%
df_fsk={sheet_name: fsk.parse(sheet_name) 
          for sheet_name in fsk.sheet_names}

# %%
df_fsk
# Out:
# {'38000':              Unnamed: 0        Unnamed: 1            Unnamed: 2    Unnamed: 3  \
#  0                   NaN               NaN                   NaN           NaN
#  1                   NaN               NaN                   NaN           NaN
#  2                   NaN               NaN                   NaN           NaN
#  3                   NaN               NaN                   NaN           NaN
#  4                Datum:  LS / WE- Nummer:  Prüfauftrags-nummer:  Chargen-Nr.:
#  5   2015-09-18 00:00:00              9611                 50827           NaN
#  6   2015-09-23 00:00:00              9213                 50636           NaN
#  7                   NaN               NaN                   NaN           NaN
#  8                   NaN               NaN                   NaN           NaN
#  9                   NaN               NaN                   NaN           NaN
#  10                  NaN               NaN                   NaN           NaN
# ...

# %%
df_fsk[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-ceab3de84133> in <module>()
# ----> 1 df_fsk[0]
#
# KeyError: 0

# %%
df_fsk[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-4871f6a25994> in <module>()
# ----> 1 df_fsk[1]
#
# KeyError: 1

# %%
df_fsk["38823"]
# Out:
#              Unnamed: 0        Unnamed: 1            Unnamed: 2    Unnamed: 3  \
# 0                   NaN               NaN                   NaN           NaN
# 1                   NaN               NaN                   NaN           NaN
# 2                   NaN               NaN                   NaN           NaN
# 3                   NaN               NaN                   NaN           NaN
# 4                Datum:  LS / WE- Nummer:  Prüfauftrags-nummer:  Chargen-Nr.:
# 5   2015-10-05 00:00:00             10273                 51104           NaN
# 6   2015-10-08 00:00:00             10356                 51163           NaN
# 7   2015-10-09 00:00:00             10516                 51241           NaN
# 8   2015-10-12 00:00:00             10517                 51242           NaN
# 9   2015-11-03 00:00:00             11324                 51662           NaN
# 10  2015-11-12 00:00:00             11653                 51820           NaN
# ...

# %%
df_fsk.keys()
# Out:
# dict_keys(['83002', '38816', '38945', '38947', '38966', '38983', '71231', '38908', '38002', '38000', '38812', '38823', '38875', '38896', '38893', '38906', '71229'])

# %%
fsk71231 = df_fsk["71231"]

# %%
fsk71231
# Out:
#               Unnamed: 0        Unnamed: 1            Unnamed: 2  \
# 0                    NaN               NaN                   NaN
# 1                    NaN               NaN                   NaN
# 2                    NaN               NaN                   NaN
# 3                    NaN               NaN                   NaN
# 4                 Datum:  LS / WE- Nummer:  Prüfauftrags-nummer:
# 5    2015-09-14 00:00:00              9554                 50802
# 6    2015-09-15 00:00:00              9613                 50828
# 7    2015-09-17 00:00:00              9733                 50867
# 8    2015-09-18 00:00:00              9792                 50890
# 9    2015-09-18 00:00:00              8974                 50906
# 10   2015-10-02 00:00:00             10240                 51083
# 11   2015-10-02 00:00:00             10274                 51105
# 12   2015-10-05 00:00:00             10312                 51136
# ...

# %%
fsk71231.iloc[0]
# Out:
# Unnamed: 0                       NaN
# Unnamed: 1                       NaN
# Unnamed: 2                       NaN
# Unnamed: 3                       NaN
# Unnamed: 4                       NaN
# Teilename:            Teilenummer:
# Unnamed: 6                       NaN
# Unnamed: 7                       NaN
# Unnamed: 8                       NaN
# Axiallager                     71231
# Unnamed: 10                      NaN
# Unnamed: 11                      NaN
# Unnamed: 12                      NaN
# Unnamed: 13                      NaN
# Unnamed: 14                      NaN
# Unnamed: 15                      NaN
# Unnamed: 16                      NaN
# Unnamed: 17                      NaN
# Unnamed: 18                      NaN
# Unnamed: 19                      NaN
# Fehlerkennkarte    KD-Nr.: 10135
# Unnamed: 21                      NaN
# Unnamed: 22                      NaN
# Unnamed: 23                      NaN
# Unnamed: 24                      NaN
# ...

# %%
fsk71231.loc[0]
# Out:
# Unnamed: 0                       NaN
# Unnamed: 1                       NaN
# Unnamed: 2                       NaN
# Unnamed: 3                       NaN
# Unnamed: 4                       NaN
# Teilename:            Teilenummer:
# Unnamed: 6                       NaN
# Unnamed: 7                       NaN
# Unnamed: 8                       NaN
# Axiallager                     71231
# Unnamed: 10                      NaN
# Unnamed: 11                      NaN
# Unnamed: 12                      NaN
# Unnamed: 13                      NaN
# Unnamed: 14                      NaN
# Unnamed: 15                      NaN
# Unnamed: 16                      NaN
# Unnamed: 17                      NaN
# Unnamed: 18                      NaN
# Unnamed: 19                      NaN
# Fehlerkennkarte    KD-Nr.: 10135
# Unnamed: 21                      NaN
# Unnamed: 22                      NaN
# Unnamed: 23                      NaN
# Unnamed: 24                      NaN
# ...

# %%
fsk71231.iloc[4]
# Out:
# Unnamed: 0                           Datum:
# Unnamed: 1                 LS / WE- Nummer:
# Unnamed: 2             Prüfauftrags-nummer:
# Unnamed: 3                     Chargen-Nr.:
# Unnamed: 4                Gesamt-stückzahl:
# Teilename:          Beschädigungam Lagerpad
# Unnamed: 6          Aufplattierung Lagerpad
# Unnamed: 7         Beschädigung Außenkontur
# Unnamed: 8         Beschädigung Innenkontur
# Axiallager            Beschädigung Ölablauf
# Unnamed: 10        Beschädigung Dichtfläche
# Unnamed: 11        Beschädigung Querbohrung
# Unnamed: 12           Beschädigung Öltasche
# Unnamed: 13                     Ölige Teile
# Unnamed: 14                      Rückstände
# Unnamed: 15                     Sonstiges 1
# Unnamed: 16                     Sonstiges 2
# Unnamed: 17                     Sonstiges 3
# Unnamed: 18                     Sonstiges 4
# Unnamed: 19                     Sonstiges 5
# Fehlerkennkarte      Summe\nn.i.O.\n[Stück]
# ...

# %%
fsk71231.columns = fsk71231.iloc[4]

# %%
fsk71231.drop(fsk71231.index[0:5])
# Out:
# 4                 Datum: LS / WE- Nummer: Prüfauftrags-nummer: Chargen-Nr.:  \
# 5    2015-09-14 00:00:00             9554                50802          NaN
# 6    2015-09-15 00:00:00             9613                50828          NaN
# 7    2015-09-17 00:00:00             9733                50867          NaN
# 8    2015-09-18 00:00:00             9792                50890          NaN
# 9    2015-09-18 00:00:00             8974                50906          NaN
# 10   2015-10-02 00:00:00            10240                51083          NaN
# 11   2015-10-02 00:00:00            10274                51105          NaN
# 12   2015-10-05 00:00:00            10312                51136          NaN
# 13   2015-10-06 00:00:00            10354                51161          NaN
# 14   2015-10-07 00:00:00            10415                51195          NaN
# 15   2015-10-08 00:00:00            10469                51225          NaN
# ...

# %%
fsk71231
# Out:
# 4                 Datum:  LS / WE- Nummer:  Prüfauftrags-nummer:  \
# 0                    NaN               NaN                   NaN
# 1                    NaN               NaN                   NaN
# 2                    NaN               NaN                   NaN
# 3                    NaN               NaN                   NaN
# 4                 Datum:  LS / WE- Nummer:  Prüfauftrags-nummer:
# 5    2015-09-14 00:00:00              9554                 50802
# 6    2015-09-15 00:00:00              9613                 50828
# 7    2015-09-17 00:00:00              9733                 50867
# 8    2015-09-18 00:00:00              9792                 50890
# 9    2015-09-18 00:00:00              8974                 50906
# 10   2015-10-02 00:00:00             10240                 51083
# 11   2015-10-02 00:00:00             10274                 51105
# 12   2015-10-05 00:00:00             10312                 51136
# ...

# %%
fsk71231[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\c.heinbockel\Programme\WinPython-32bit-3.6.0.1Qt5\python-3.6.0\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
fsk71231[[0]]
# Out:
# 4                 Datum:
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                 Datum:
# 5    2015-09-14 00:00:00
# 6    2015-09-15 00:00:00
# 7    2015-09-17 00:00:00
# 8    2015-09-18 00:00:00
# 9    2015-09-18 00:00:00
# 10   2015-10-02 00:00:00
# 11   2015-10-02 00:00:00
# 12   2015-10-05 00:00:00
# 13   2015-10-06 00:00:00
# 14   2015-10-07 00:00:00
# 15   2015-10-08 00:00:00
# 16   2015-10-14 00:00:00
# 17   2015-10-19 00:00:00
# 18   2015-10-20 00:00:00
# 19   2015-10-20 00:00:00
# 20   2015-10-21 00:00:00
# 21   2015-10-26 00:00:00
# 22   2015-10-27 00:00:00
# 23   2015-10-29 00:00:00
# 24   2015-10-30 00:00:00
# 25   2015-11-03 00:00:00
# 26   2015-11-03 00:00:00
# 27   2015-11-06 00:00:00
# 28   2015-11-09 00:00:00
# 29   2015-11-10 00:00:00
# ..                   ...
# 185  2017-03-23 00:00:00
# 186  2017-05-03 00:00:00
# 187  2017-05-05 00:00:00
# 188  2017-05-11 00:00:00
# 189  2017-05-15 00:00:00
# ...

# %%
print(fsk71231.loc[fsk71231[0] > "2015-09-15 00:00:00")
# Out:
#   File "<ipython-input-37-d640622800da>", line 1
#     print(fsk71231.loc[fsk71231[0] > "2015-09-15 00:00:00")
#                                                           ^
# SyntaxError: invalid syntax

# %%
pd.to_datetime(fsk71231["Datum:"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\c.heinbockel\Programme\WinPython-32bit-3.6.0.1Qt5\python-3.6.0\lib\site-packages\pandas\tseries\tools.py in _convert_listlike(arg, box, format, name, tz)
#     409             try:
# --> 410                 values, tz = tslib.datetime_to_datetime64(arg)
#     411                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\tslib.pyx in pandas.tslib.datetime_to_datetime64 (pandas\tslib.c:33358)()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-0c45ad312009> in <module>()
# ----> 1 pd.to_datetime(fsk71231["Datum:"])
#
# ...

# %%
fsk71231["Datum:"]
# Out:
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                   Datum:
# 5      2015-09-14 00:00:00
# 6      2015-09-15 00:00:00
# 7      2015-09-17 00:00:00
# 8      2015-09-18 00:00:00
# 9      2015-09-18 00:00:00
# 10     2015-10-02 00:00:00
# 11     2015-10-02 00:00:00
# 12     2015-10-05 00:00:00
# 13     2015-10-06 00:00:00
# 14     2015-10-07 00:00:00
# 15     2015-10-08 00:00:00
# 16     2015-10-14 00:00:00
# 17     2015-10-19 00:00:00
# 18     2015-10-20 00:00:00
# 19     2015-10-20 00:00:00
# 20     2015-10-21 00:00:00
# 21     2015-10-26 00:00:00
# 22     2015-10-27 00:00:00
# 23     2015-10-29 00:00:00
# 24     2015-10-30 00:00:00
# 25     2015-11-03 00:00:00
# 26     2015-11-03 00:00:00
# 27     2015-11-06 00:00:00
# 28     2015-11-09 00:00:00
# 29     2015-11-10 00:00:00
#               ...
# 185    2017-03-23 00:00:00
# 186    2017-05-03 00:00:00
# 187    2017-05-05 00:00:00
# ...

# %%
pd.to_datetime(fsk71231["Datum:"], format='%YY-%mm-%dd %h:%m:%s', errors='ignore')
# Out:
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                   Datum:
# 5      2015-09-14 00:00:00
# 6      2015-09-15 00:00:00
# 7      2015-09-17 00:00:00
# 8      2015-09-18 00:00:00
# 9      2015-09-18 00:00:00
# 10     2015-10-02 00:00:00
# 11     2015-10-02 00:00:00
# 12     2015-10-05 00:00:00
# 13     2015-10-06 00:00:00
# 14     2015-10-07 00:00:00
# 15     2015-10-08 00:00:00
# 16     2015-10-14 00:00:00
# 17     2015-10-19 00:00:00
# 18     2015-10-20 00:00:00
# 19     2015-10-20 00:00:00
# 20     2015-10-21 00:00:00
# 21     2015-10-26 00:00:00
# 22     2015-10-27 00:00:00
# 23     2015-10-29 00:00:00
# 24     2015-10-30 00:00:00
# 25     2015-11-03 00:00:00
# 26     2015-11-03 00:00:00
# 27     2015-11-06 00:00:00
# 28     2015-11-09 00:00:00
# 29     2015-11-10 00:00:00
#               ...
# 185    2017-03-23 00:00:00
# 186    2017-05-03 00:00:00
# 187    2017-05-05 00:00:00
# ...

# %%
datumtest = pd.to_datetime(fsk71231["Datum:"], format='%YY-%mm-%dd %h:%m:%s', errors='ignore')

# %%
datumtest
# Out:
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                   Datum:
# 5      2015-09-14 00:00:00
# 6      2015-09-15 00:00:00
# 7      2015-09-17 00:00:00
# 8      2015-09-18 00:00:00
# 9      2015-09-18 00:00:00
# 10     2015-10-02 00:00:00
# 11     2015-10-02 00:00:00
# 12     2015-10-05 00:00:00
# 13     2015-10-06 00:00:00
# 14     2015-10-07 00:00:00
# 15     2015-10-08 00:00:00
# 16     2015-10-14 00:00:00
# 17     2015-10-19 00:00:00
# 18     2015-10-20 00:00:00
# 19     2015-10-20 00:00:00
# 20     2015-10-21 00:00:00
# 21     2015-10-26 00:00:00
# 22     2015-10-27 00:00:00
# 23     2015-10-29 00:00:00
# 24     2015-10-30 00:00:00
# 25     2015-11-03 00:00:00
# 26     2015-11-03 00:00:00
# 27     2015-11-06 00:00:00
# 28     2015-11-09 00:00:00
# 29     2015-11-10 00:00:00
#               ...
# 185    2017-03-23 00:00:00
# 186    2017-05-03 00:00:00
# 187    2017-05-05 00:00:00
# ...

# %%
datumtest.loc[13]
# Out:
# Timestamp('2015-10-06 00:00:00')

# %%
print(datumtest.loc[datumtest[
    "Datum:"] > "2015-09-15 00:00:00"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:8543)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-5a3071b8bbf3> in <module>()
#       1 print(datumtest.loc[datumtest[
# ----> 2     "Datum:"] > "2015-09-15 00:00:00"])
#
# C:\Users\c.heinbockel\Programme\WinPython-32bit-3.6.0.1Qt5\python-3.6.0\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     601         key = com._apply_if_callable(key, self)
#     602         try:
# --> 603             result = self.index.get_value(self, key)
#     604
# ...

# %%
datumtest[[0]]
# Out:
# 0    NaN
# Name: Datum:, dtype: object

# %%
datumtest[0]
# Out:
# nan

# %% [markdown]
# datumtest

# %%
datumtest
# Out:
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                   Datum:
# 5      2015-09-14 00:00:00
# 6      2015-09-15 00:00:00
# 7      2015-09-17 00:00:00
# 8      2015-09-18 00:00:00
# 9      2015-09-18 00:00:00
# 10     2015-10-02 00:00:00
# 11     2015-10-02 00:00:00
# 12     2015-10-05 00:00:00
# 13     2015-10-06 00:00:00
# 14     2015-10-07 00:00:00
# 15     2015-10-08 00:00:00
# 16     2015-10-14 00:00:00
# 17     2015-10-19 00:00:00
# 18     2015-10-20 00:00:00
# 19     2015-10-20 00:00:00
# 20     2015-10-21 00:00:00
# 21     2015-10-26 00:00:00
# 22     2015-10-27 00:00:00
# 23     2015-10-29 00:00:00
# 24     2015-10-30 00:00:00
# 25     2015-11-03 00:00:00
# 26     2015-11-03 00:00:00
# 27     2015-11-06 00:00:00
# 28     2015-11-09 00:00:00
# 29     2015-11-10 00:00:00
#               ...
# 185    2017-03-23 00:00:00
# 186    2017-05-03 00:00:00
# 187    2017-05-05 00:00:00
# ...

# %%
datumtest
# Out:
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                   Datum:
# 5      2015-09-14 00:00:00
# 6      2015-09-15 00:00:00
# 7      2015-09-17 00:00:00
# 8      2015-09-18 00:00:00
# 9      2015-09-18 00:00:00
# 10     2015-10-02 00:00:00
# 11     2015-10-02 00:00:00
# 12     2015-10-05 00:00:00
# 13     2015-10-06 00:00:00
# 14     2015-10-07 00:00:00
# 15     2015-10-08 00:00:00
# 16     2015-10-14 00:00:00
# 17     2015-10-19 00:00:00
# 18     2015-10-20 00:00:00
# 19     2015-10-20 00:00:00
# 20     2015-10-21 00:00:00
# 21     2015-10-26 00:00:00
# 22     2015-10-27 00:00:00
# 23     2015-10-29 00:00:00
# 24     2015-10-30 00:00:00
# 25     2015-11-03 00:00:00
# 26     2015-11-03 00:00:00
# 27     2015-11-06 00:00:00
# 28     2015-11-09 00:00:00
# 29     2015-11-10 00:00:00
#               ...
# 185    2017-03-23 00:00:00
# 186    2017-05-03 00:00:00
# 187    2017-05-05 00:00:00
# ...

# %%
fsk71231["Datum:"] = pd.to_datetime(fsk71231["Datum:"], format='%YY-%mm-%dd %h:%m:%s', errors='ignore')

# %%
fsk71231["Datum:"]
# Out:
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                   Datum:
# 5      2015-09-14 00:00:00
# 6      2015-09-15 00:00:00
# 7      2015-09-17 00:00:00
# 8      2015-09-18 00:00:00
# 9      2015-09-18 00:00:00
# 10     2015-10-02 00:00:00
# 11     2015-10-02 00:00:00
# 12     2015-10-05 00:00:00
# 13     2015-10-06 00:00:00
# 14     2015-10-07 00:00:00
# 15     2015-10-08 00:00:00
# 16     2015-10-14 00:00:00
# 17     2015-10-19 00:00:00
# 18     2015-10-20 00:00:00
# 19     2015-10-20 00:00:00
# 20     2015-10-21 00:00:00
# 21     2015-10-26 00:00:00
# 22     2015-10-27 00:00:00
# 23     2015-10-29 00:00:00
# 24     2015-10-30 00:00:00
# 25     2015-11-03 00:00:00
# 26     2015-11-03 00:00:00
# 27     2015-11-06 00:00:00
# 28     2015-11-09 00:00:00
# 29     2015-11-10 00:00:00
#               ...
# 185    2017-03-23 00:00:00
# 186    2017-05-03 00:00:00
# 187    2017-05-05 00:00:00
# ...

# %%
fsk71231["Datum:"].loc[22]
# Out:
# Timestamp('2015-10-27 00:00:00')

# %%
fsk71231["Datum:"]
# Out:
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                   Datum:
# 5      2015-09-14 00:00:00
# 6      2015-09-15 00:00:00
# 7      2015-09-17 00:00:00
# 8      2015-09-18 00:00:00
# 9      2015-09-18 00:00:00
# 10     2015-10-02 00:00:00
# 11     2015-10-02 00:00:00
# 12     2015-10-05 00:00:00
# 13     2015-10-06 00:00:00
# 14     2015-10-07 00:00:00
# 15     2015-10-08 00:00:00
# 16     2015-10-14 00:00:00
# 17     2015-10-19 00:00:00
# 18     2015-10-20 00:00:00
# 19     2015-10-20 00:00:00
# 20     2015-10-21 00:00:00
# 21     2015-10-26 00:00:00
# 22     2015-10-27 00:00:00
# 23     2015-10-29 00:00:00
# 24     2015-10-30 00:00:00
# 25     2015-11-03 00:00:00
# 26     2015-11-03 00:00:00
# 27     2015-11-06 00:00:00
# 28     2015-11-09 00:00:00
# 29     2015-11-10 00:00:00
#               ...
# 185    2017-03-23 00:00:00
# 186    2017-05-03 00:00:00
# 187    2017-05-05 00:00:00
# ...

# %%
fsk71231["Datum:"] > pd.to_datetime('2016-05-01')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-8e35db6922d0> in <module>()
# ----> 1 fsk71231["Datum:"] > pd.to_datetime('2016-05-01')
#
# C:\Users\c.heinbockel\Programme\WinPython-32bit-3.6.0.1Qt5\python-3.6.0\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     853
#     854             with np.errstate(all='ignore'):
# --> 855                 res = na_op(values, other)
#     856             if isscalar(res):
#     857                 raise TypeError('Could not compare %s type with Series' %
#
# C:\Users\c.heinbockel\Programme\WinPython-32bit-3.6.0.1Qt5\python-3.6.0\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     757
#     758         if is_object_dtype(x.dtype):
# --> 759             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     760         else:
#     761
#
# ...

# %%
pd.to_datetime('2016-05-01')
# Out:
# Timestamp('2016-05-01 00:00:00')

# %%
fsk71231["Datum:"].loc[6]
# Out:
# Timestamp('2015-09-15 00:00:00')

# %%
fsk71231["Datum:"].loc[6] < pd.to_datetime('2016-05-01')
# Out:
# True

# %%
fsk71231["Datum:"].loc[6] > pd.to_datetime('2016-05-01')
# Out:
# False

# %%
fsk71231["Datum:"].loc[6] > pd.to_datetime('2016-05')
# Out:
# False

# %%
fsk71231["Datum:"].loc[6] < pd.to_datetime('2016-05')
# Out:
# True

# %%
fsk71231["Datum:"].loc[1]
# Out:
# nan

# %%
fsk71231
# Out:
# 4                 Datum:  LS / WE- Nummer:  Prüfauftrags-nummer:  \
# 0                    NaN               NaN                   NaN
# 1                    NaN               NaN                   NaN
# 2                    NaN               NaN                   NaN
# 3                    NaN               NaN                   NaN
# 4                 Datum:  LS / WE- Nummer:  Prüfauftrags-nummer:
# 5    2015-09-14 00:00:00              9554                 50802
# 6    2015-09-15 00:00:00              9613                 50828
# 7    2015-09-17 00:00:00              9733                 50867
# 8    2015-09-18 00:00:00              9792                 50890
# 9    2015-09-18 00:00:00              8974                 50906
# 10   2015-10-02 00:00:00             10240                 51083
# 11   2015-10-02 00:00:00             10274                 51105
# 12   2015-10-05 00:00:00             10312                 51136
# ...

# %%
fsk71231 = fsk71231.drop(fsk71231.index[0:5])

# %%
fsk71231
# Out:
# 4                 Datum: LS / WE- Nummer: Prüfauftrags-nummer: Chargen-Nr.:  \
# 5    2015-09-14 00:00:00             9554                50802          NaN
# 6    2015-09-15 00:00:00             9613                50828          NaN
# 7    2015-09-17 00:00:00             9733                50867          NaN
# 8    2015-09-18 00:00:00             9792                50890          NaN
# 9    2015-09-18 00:00:00             8974                50906          NaN
# 10   2015-10-02 00:00:00            10240                51083          NaN
# 11   2015-10-02 00:00:00            10274                51105          NaN
# 12   2015-10-05 00:00:00            10312                51136          NaN
# 13   2015-10-06 00:00:00            10354                51161          NaN
# 14   2015-10-07 00:00:00            10415                51195          NaN
# 15   2015-10-08 00:00:00            10469                51225          NaN
# ...

# %%
fsk71231.drop(fsk71231.index[207:215])
# Out:
# 4                 Datum: LS / WE- Nummer: Prüfauftrags-nummer: Chargen-Nr.:  \
# 5    2015-09-14 00:00:00             9554                50802          NaN
# 6    2015-09-15 00:00:00             9613                50828          NaN
# 7    2015-09-17 00:00:00             9733                50867          NaN
# 8    2015-09-18 00:00:00             9792                50890          NaN
# 9    2015-09-18 00:00:00             8974                50906          NaN
# 10   2015-10-02 00:00:00            10240                51083          NaN
# 11   2015-10-02 00:00:00            10274                51105          NaN
# 12   2015-10-05 00:00:00            10312                51136          NaN
# 13   2015-10-06 00:00:00            10354                51161          NaN
# 14   2015-10-07 00:00:00            10415                51195          NaN
# 15   2015-10-08 00:00:00            10469                51225          NaN
# ...

# %%
fsk71231.drop(fsk71231.index[207:214])
# Out:
# 4                 Datum: LS / WE- Nummer: Prüfauftrags-nummer: Chargen-Nr.:  \
# 5    2015-09-14 00:00:00             9554                50802          NaN
# 6    2015-09-15 00:00:00             9613                50828          NaN
# 7    2015-09-17 00:00:00             9733                50867          NaN
# 8    2015-09-18 00:00:00             9792                50890          NaN
# 9    2015-09-18 00:00:00             8974                50906          NaN
# 10   2015-10-02 00:00:00            10240                51083          NaN
# 11   2015-10-02 00:00:00            10274                51105          NaN
# 12   2015-10-05 00:00:00            10312                51136          NaN
# 13   2015-10-06 00:00:00            10354                51161          NaN
# 14   2015-10-07 00:00:00            10415                51195          NaN
# 15   2015-10-08 00:00:00            10469                51225          NaN
# ...

# %%
fsk71231
# Out:
# 4                 Datum: LS / WE- Nummer: Prüfauftrags-nummer: Chargen-Nr.:  \
# 5    2015-09-14 00:00:00             9554                50802          NaN
# 6    2015-09-15 00:00:00             9613                50828          NaN
# 7    2015-09-17 00:00:00             9733                50867          NaN
# 8    2015-09-18 00:00:00             9792                50890          NaN
# 9    2015-09-18 00:00:00             8974                50906          NaN
# 10   2015-10-02 00:00:00            10240                51083          NaN
# 11   2015-10-02 00:00:00            10274                51105          NaN
# 12   2015-10-05 00:00:00            10312                51136          NaN
# 13   2015-10-06 00:00:00            10354                51161          NaN
# 14   2015-10-07 00:00:00            10415                51195          NaN
# 15   2015-10-08 00:00:00            10469                51225          NaN
# ...

# %%
fsk71231.loc[206]
# Out:
# 4
# Datum:                      2017-06-12 00:00:00
# LS / WE- Nummer:                          38149
# Prüfauftrags-nummer:                       2292
# Chargen-Nr.:                                NaN
# Gesamt-stückzahl:                          5618
# Beschädigungam Lagerpad                     103
# Aufplattierung Lagerpad                     NaN
# Beschädigung Außenkontur                    241
# Beschädigung Innenkontur                      7
# Beschädigung Ölablauf                       NaN
# Beschädigung Dichtfläche                     45
# Beschädigung Querbohrung                    NaN
# Beschädigung Öltasche                       NaN
# Ölige Teile                                 NaN
# Rückstände                                  NaN
# Sonstiges 1                                 580
# Sonstiges 2                                 297
# Sonstiges 3                                   1
# Sonstiges 4                                 NaN
# ...

# %%
fsk71231 = fsk71231.drop(fsk71231.index[207:214])

# %%
fsk71231
# Out:
# 4                 Datum: LS / WE- Nummer: Prüfauftrags-nummer: Chargen-Nr.:  \
# 5    2015-09-14 00:00:00             9554                50802          NaN
# 6    2015-09-15 00:00:00             9613                50828          NaN
# 7    2015-09-17 00:00:00             9733                50867          NaN
# 8    2015-09-18 00:00:00             9792                50890          NaN
# 9    2015-09-18 00:00:00             8974                50906          NaN
# 10   2015-10-02 00:00:00            10240                51083          NaN
# 11   2015-10-02 00:00:00            10274                51105          NaN
# 12   2015-10-05 00:00:00            10312                51136          NaN
# 13   2015-10-06 00:00:00            10354                51161          NaN
# 14   2015-10-07 00:00:00            10415                51195          NaN
# 15   2015-10-08 00:00:00            10469                51225          NaN
# ...

# %%
fsk71231 = fsk71231.drop(fsk71231.index[206:-1])

# %%
fsk71231
# Out:
# 4                 Datum: LS / WE- Nummer: Prüfauftrags-nummer: Chargen-Nr.:  \
# 5    2015-09-14 00:00:00             9554                50802          NaN
# 6    2015-09-15 00:00:00             9613                50828          NaN
# 7    2015-09-17 00:00:00             9733                50867          NaN
# 8    2015-09-18 00:00:00             9792                50890          NaN
# 9    2015-09-18 00:00:00             8974                50906          NaN
# 10   2015-10-02 00:00:00            10240                51083          NaN
# 11   2015-10-02 00:00:00            10274                51105          NaN
# 12   2015-10-05 00:00:00            10312                51136          NaN
# 13   2015-10-06 00:00:00            10354                51161          NaN
# 14   2015-10-07 00:00:00            10415                51195          NaN
# 15   2015-10-08 00:00:00            10469                51225          NaN
# ...

# %%
fsk71231["Datum:"] > pd.to_datetime('2016-05-01')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-8e35db6922d0> in <module>()
# ----> 1 fsk71231["Datum:"] > pd.to_datetime('2016-05-01')
#
# C:\Users\c.heinbockel\Programme\WinPython-32bit-3.6.0.1Qt5\python-3.6.0\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     853
#     854             with np.errstate(all='ignore'):
# --> 855                 res = na_op(values, other)
#     856             if isscalar(res):
#     857                 raise TypeError('Could not compare %s type with Series' %
#
# C:\Users\c.heinbockel\Programme\WinPython-32bit-3.6.0.1Qt5\python-3.6.0\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     757
#     758         if is_object_dtype(x.dtype):
# --> 759             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     760         else:
#     761
#
# ...

# %%
fsk71231.dropna(subset=["Datum:"])
# Out:
# 4                 Datum: LS / WE- Nummer: Prüfauftrags-nummer: Chargen-Nr.:  \
# 5    2015-09-14 00:00:00             9554                50802          NaN
# 6    2015-09-15 00:00:00             9613                50828          NaN
# 7    2015-09-17 00:00:00             9733                50867          NaN
# 8    2015-09-18 00:00:00             9792                50890          NaN
# 9    2015-09-18 00:00:00             8974                50906          NaN
# 10   2015-10-02 00:00:00            10240                51083          NaN
# 11   2015-10-02 00:00:00            10274                51105          NaN
# 12   2015-10-05 00:00:00            10312                51136          NaN
# 13   2015-10-06 00:00:00            10354                51161          NaN
# 14   2015-10-07 00:00:00            10415                51195          NaN
# 15   2015-10-08 00:00:00            10469                51225          NaN
# ...

# %%
fsk71231["Datum:"] > pd.to_datetime('2016-05-01')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-8e35db6922d0> in <module>()
# ----> 1 fsk71231["Datum:"] > pd.to_datetime('2016-05-01')
#
# C:\Users\c.heinbockel\Programme\WinPython-32bit-3.6.0.1Qt5\python-3.6.0\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     853
#     854             with np.errstate(all='ignore'):
# --> 855                 res = na_op(values, other)
#     856             if isscalar(res):
#     857                 raise TypeError('Could not compare %s type with Series' %
#
# C:\Users\c.heinbockel\Programme\WinPython-32bit-3.6.0.1Qt5\python-3.6.0\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     757
#     758         if is_object_dtype(x.dtype):
# --> 759             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     760         else:
#     761
#
# ...

# %%
fsk71231 = fsk71231.dropna(subset=["Datum:"])

# %%
fsk71231["Datum:"]
# Out:
# 5      2015-09-14 00:00:00
# 6      2015-09-15 00:00:00
# 7      2015-09-17 00:00:00
# 8      2015-09-18 00:00:00
# 9      2015-09-18 00:00:00
# 10     2015-10-02 00:00:00
# 11     2015-10-02 00:00:00
# 12     2015-10-05 00:00:00
# 13     2015-10-06 00:00:00
# 14     2015-10-07 00:00:00
# 15     2015-10-08 00:00:00
# 16     2015-10-14 00:00:00
# 17     2015-10-19 00:00:00
# 18     2015-10-20 00:00:00
# 19     2015-10-20 00:00:00
# 20     2015-10-21 00:00:00
# 21     2015-10-26 00:00:00
# 22     2015-10-27 00:00:00
# 23     2015-10-29 00:00:00
# 24     2015-10-30 00:00:00
# 25     2015-11-03 00:00:00
# 26     2015-11-03 00:00:00
# 27     2015-11-06 00:00:00
# 28     2015-11-09 00:00:00
# 29     2015-11-10 00:00:00
# 30     2015-11-13 00:00:00
# 31     2015-11-19 00:00:00
# 32     2015-11-19 00:00:00
# 33     2015-11-23 00:00:00
# 34     2015-11-26 00:00:00
#               ...
# 177    2017-02-07 00:00:00
# 178    2017-02-08 00:00:00
# 179    2017-02-13 00:00:00
# ...

# %%
testi = fsk71231["Datum:"] > pd.to_datetime('2016-05-01')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-640db26cebe7> in <module>()
# ----> 1 testi = fsk71231["Datum:"] > pd.to_datetime('2016-05-01')
#
# C:\Users\c.heinbockel\Programme\WinPython-32bit-3.6.0.1Qt5\python-3.6.0\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     853
#     854             with np.errstate(all='ignore'):
# --> 855                 res = na_op(values, other)
#     856             if isscalar(res):
#     857                 raise TypeError('Could not compare %s type with Series' %
#
# C:\Users\c.heinbockel\Programme\WinPython-32bit-3.6.0.1Qt5\python-3.6.0\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     757
#     758         if is_object_dtype(x.dtype):
# --> 759             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     760         else:
#     761
#
# ...

# %%
testi = fsk71231["Datum:"] > '2016-05-01'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-511472bd6fe9> in <module>()
# ----> 1 testi = fsk71231["Datum:"] > '2016-05-01'
#
# C:\Users\c.heinbockel\Programme\WinPython-32bit-3.6.0.1Qt5\python-3.6.0\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     853
#     854             with np.errstate(all='ignore'):
# --> 855                 res = na_op(values, other)
#     856             if isscalar(res):
#     857                 raise TypeError('Could not compare %s type with Series' %
#
# C:\Users\c.heinbockel\Programme\WinPython-32bit-3.6.0.1Qt5\python-3.6.0\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     757
#     758         if is_object_dtype(x.dtype):
# --> 759             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     760         else:
#     761
#
# ...

# %%
pd.to_datetime('2016-05-01')
# Out:
# Timestamp('2016-05-01 00:00:00')

# %%
type(pd.to_datetime('2016-05-01'))
# Out:
# pandas.tslib.Timestamp

# %%
type(fsk71231["Datum:"])
# Out:
# pandas.core.series.Series
