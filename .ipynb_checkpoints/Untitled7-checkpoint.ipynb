# %%
# %matplotlib inline

# import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import locale

locale.setlocale(locale.LC_ALL, 'German')

d = "2017-W23"
r = datetime.datetime.strptime(d + '-0', "%Y-W%W-%w")
print(r)

fsk = pd.ExcelFile("Fehlerkennkarte extern NEU.xls")
print(fsk.sheet_names)

dfalle = {sheet_name: fsk.parse(sheet_name) for sheet_name in fsk.sheet_names}

print(dfalle.keys())

df = dfalle[str(71231)]
print(df.head())
df = df.dropna(subset=['Unnamed: 0'])
df.columns = df.iloc[0]
df = df.drop(df.index[0])
df['Datum:'] = pd.to_datetime(df['Datum:'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
df = df.set_index('Datum:').groupby(pd.TimeGrouper('W')).sum()
df.columns.name = None
summe_io = df.columns[20]
summe_nio = df.columns[18]

spalten = [summe_io, summe_nio]

    
print(df[summe_io].loc[r].sum() > 0)
print(df[summe_io].loc[r].sum())
print(df.index)
print("")
print(df[spalten].loc[r])
print("")

colors = ['green', 'red']

ax  = df[spalten].loc[r].plot(kind='bar', rot=0, color=colors)
for p in ax.patches: 
    # ax.annotate(str(p.get_height()), xy=(p.get_x(), p.get_height()))
    ax.annotate(locale.format('%.0f', np.round(p.get_height() ,decimals=0), True), (p.get_x()+p.get_width()/2., p.get_height()), ha='center', va='center', xytext=(0, -10), textcoords='offset points', color='white', fontsize=20, weight='heavy')
print(ax.patches)
plt.tight_layout()
fig = ax.get_figure()

fig.savefig(str(71231)+"-"+d+"-test.pdf")
# Out:
# 2017-06-11 00:00:00
# ['83002', '38816', '38945', '38947', '38966', '38983', '71231', '38908', '38002', '38000', '38812', '38823', '38875', '38896', '38893', '38906', '71229']
# dict_keys(['83002', '38816', '38945', '38947', '38966', '38983', '71231', '38908', '38002', '38000', '38812', '38823', '38875', '38896', '38893', '38906', '71229'])
#   Unnamed: 0        Unnamed: 1            Unnamed: 2    Unnamed: 3  \
# 0        NaN               NaN                   NaN           NaN
# 1        NaN               NaN                   NaN           NaN
# 2        NaN               NaN                   NaN           NaN
# 3        NaN               NaN                   NaN           NaN
# 4     Datum:  LS / WE- Nummer:  Prüfauftrags-nummer:  Chargen-Nr.:
#
#           Unnamed: 4                              Teilename:     \
# 0                NaN                             Teilenummer:
# 1                NaN                             Vergrößerung:
# 2                NaN                                        NaN
# 3                NaN  Fehlermerkmale entsprechend Fehlerkatalog
# 4  Gesamt-stückzahl:                    Beschädigungam Lagerpad
#
#                 Unnamed: 6                Unnamed: 7  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4  Aufplattierung Lagerpad  Beschädigung Außenkontur
#
#                  Unnamed: 8             Axiallager     ...      Unnamed: 17  \
# 0                       NaN                  71231     ...              NaN
# 1                       NaN               3,4-Fach     ...              NaN
# 2                       NaN                    NaN     ...              NaN
# 3                       NaN                    NaN     ...              NaN
# 4  Beschädigung Innenkontur  Beschädigung Ölablauf     ...      Sonstiges 3
#
#    Unnamed: 18  Unnamed: 19         Fehlerkennkarte      Unnamed: 21  \
# 0          NaN          NaN       KD-Nr.: 10135                  NaN
# 1          NaN          NaN                     NaN              NaN
# 2          NaN          NaN                     NaN              NaN
# 3          NaN          NaN                     NaN              NaN
# 4  Sonstiges 4  Sonstiges 5  Summe\nn.i.O.\n[Stück]  Aus-schuss in %
#
#           Unnamed: 22 Unnamed: 23  Unnamed: 24           Unnamed: 25  \
# 0                 NaN         NaN          NaN                   NaN
# 1                 NaN         NaN          NaN                   NaN
# 2                 NaN         NaN          NaN                   NaN
# 3                 NaN         NaN          NaN                   NaN
# 4  Summe i.O. [Stück]  Mehr-menge  Fehl-menge:  Abgeschlossen durch:
#
#   Unnamed: 26
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4  Bemerkung:
#
# [5 rows x 27 columns]
# True
# 27195
# DatetimeIndex(['2015-09-20', '2015-09-27', '2015-10-04', '2015-10-11',
#                '2015-10-18', '2015-10-25', '2015-11-01', '2015-11-08',
#                '2015-11-15', '2015-11-22', '2015-11-29', '2015-12-06',
#                '2015-12-13', '2015-12-20', '2015-12-27', '2016-01-03',
#                '2016-01-10', '2016-01-17', '2016-01-24', '2016-01-31',
#                '2016-02-07', '2016-02-14', '2016-02-21', '2016-02-28',
#                '2016-03-06', '2016-03-13', '2016-03-20', '2016-03-27',
#                '2016-04-03', '2016-04-10', '2016-04-17', '2016-04-24',
#                '2016-05-01', '2016-05-08', '2016-05-15', '2016-05-22',
#                '2016-05-29', '2016-06-05', '2016-06-12', '2016-06-19',
#                '2016-06-26', '2016-07-03', '2016-07-10', '2016-07-17',
#                '2016-07-24', '2016-07-31', '2016-08-07', '2016-08-14',
#                '2016-08-21', '2016-08-28', '2016-09-04', '2016-09-11',
#                '2016-09-18', '2016-09-25', '2016-10-02', '2016-10-09',
#                '2016-10-16', '2016-10-23', '2016-10-30', '2016-11-06',
#                '2016-11-13', '2016-11-20', '2016-11-27', '2016-12-04',
#                '2016-12-11', '2016-12-18', '2016-12-25', '2017-01-01',
#                '2017-01-08', '2017-01-15', '2017-01-22', '2017-01-29',
#                '2017-02-05', '2017-02-12', '2017-02-19', '2017-02-26',
#                '2017-03-05', '2017-03-12', '2017-03-19', '2017-03-26',
#                '2017-04-02', '2017-04-09', '2017-04-16', '2017-04-23',
#                '2017-04-30', '2017-05-07', '2017-05-14', '2017-05-21',
#                '2017-05-28', '2017-06-04', '2017-06-11', '2017-06-18'],
#               dtype='datetime64[ns]', name='Datum:', freq='W-SUN')
#
# Summe i.O. [Stück]        27195
# Summe\nn.i.O.\n[Stück]     5431
# Name: 2017-06-11 00:00:00, dtype: int64
#
# [<matplotlib.patches.Rectangle object at 0x092D3310>, <matplotlib.patches.Rectangle object at 0x0A82ADD0>]
